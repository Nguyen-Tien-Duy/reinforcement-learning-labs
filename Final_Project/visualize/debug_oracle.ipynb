# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_raw = pd.read_parquet('../Data/data_2024-04-10_2026-04-10.parquet')
df_raw.describe()
# Out:
#        block_number  base_fee_per_gas      gas_used     gas_limit  \
# count  5.224088e+06      5.224088e+06  5.224088e+06  5.224088e+06
# mean   2.223356e+07      4.579468e+09  2.000778e+07  3.954351e+07
# std    1.508064e+06      9.739521e+09  1.081743e+07  1.108291e+07
# min    1.962152e+07      8.703865e+06  0.000000e+00  2.997070e+07
# 25%    2.092754e+07      2.458945e+08  1.293229e+07  3.000000e+07
# 50%    2.223356e+07      1.081608e+09  1.746895e+07  3.596484e+07
# 75%    2.353958e+07      5.793104e+09  2.481927e+07  4.500000e+07
# max    2.484560e+07      8.255167e+11  6.005850e+07  6.011724e+07
#
#        transaction_count          size
# count       5.224088e+06  5.224088e+06
# mean        2.022691e+02  1.015016e+05
# std         1.106095e+02  6.472966e+04
# min         0.000000e+00  1.151000e+03
# 25%         1.380000e+02  6.172600e+04
# 50%         1.790000e+02  8.553950e+04
# 75%         2.390000e+02  1.245750e+05
# max         2.753000e+03  1.956743e+06

# %%
df_oracle = pd.read_parquet('../Data/transitions_v23.parquet') 
print(df_oracle.columns)
# Out:
# Index(['action', 'reward', 'done', 'episode_id', 'timestamp', 'step_index',
#        'gas_t', 'gas_reference', 'transaction_count', 'queue_size',
#        'time_to_deadline', 'executed_volume_proxy', 'truncated', 'info_json',
#        'behavior_log_prob', 'policy_type', 's_gas_t0', 'ns_gas_t0', 's_gas_t1',
#        'ns_gas_t1', 's_gas_t2', 'ns_gas_t2', 's_congestion', 'ns_congestion',
#        's_momentum', 'ns_momentum', 's_accel', 'ns_accel', 's_surprise',
#        'ns_surprise', 's_backlog', 'ns_backlog', 's_queue', 'ns_queue',
#        's_time_left', 'ns_time_left', 's_gas_ref', 'ns_gas_ref'],
#       dtype='str')

# %%
df_oracle
# Out:
#          action    reward  done  episode_id                 timestamp  \
# 0             4  0.000000     0           0 2024-04-10 00:00:11+00:00
# 1             4 -0.304425     0           0 2024-04-10 00:00:23+00:00
# 2             4  0.340676     0           0 2024-04-10 00:00:35+00:00
# 3             4  1.101294     0           0 2024-04-10 00:00:47+00:00
# 4             4 -1.081782     0           0 2024-04-10 00:00:59+00:00
# ...         ...       ...   ...         ...                       ...
# 5224083       4  0.002790     0         729 2026-04-09 23:59:11+00:00
# 5224084       4 -0.000162     0         729 2026-04-09 23:59:23+00:00
# 5224085       4  0.005278     0         729 2026-04-09 23:59:35+00:00
# 5224086       4 -0.004119     0         729 2026-04-09 23:59:47+00:00
# 5224087       4  0.001308     1         729 2026-04-09 23:59:59+00:00
#
#          step_index         gas_t  gas_reference  transaction_count  \
# ...

# %%
import d3rlpy.algos as algos
print("DiscreteAWAC" in dir(algos))
# Out:
# False

# %%
import d3rlpy
print([name for name in dir(d3rlpy.algos) if name.startswith("Discrete") and "Config" in name])
# Out:
# ['DiscreteBCConfig', 'DiscreteBCQConfig', 'DiscreteCQLConfig', 'DiscreteDecisionTransformerConfig', 'DiscreteRandomPolicyConfig', 'DiscreteSACConfig']
